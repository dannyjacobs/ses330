# %%
## Lab_ex LRC Circuit
#Author: Kenji Doi
#Member: Patric Jackson
#Member: Johnathan McDougal
#Date: 10/03/2-17

# %%
## Introduction
#A goal of this lab is to be familiar with github, and python coding.
#To achieve the goal, the Lab3:Diode has been recycled as a topic

# %%
## Materials
#Ni-Elvis Breadboard
#100k Ohms Resistor
#0.01 uF Capacitor
#10 mH Inductor

# %%
##Method
from PIL import Image
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

img = Image.open('LRC_circuit_diagram.png')
img.show()

#Ch0 corresponds to input, and ch1 is output.
#First step is determinning a resonance frequency.
#Using equation f = 1/ (2*pi*sqrt(L*C)), a theoretical value 15.9 kHz calculated.
#With using bode plot function on Ni-Elvis, an actual value found at  16.6 kHz
#An error is 3.77 % which caused by internal resitances of tools used in the circuit

#While using the bode plot, gain and frequency datas were recorded, and following. FileName = LRC_data_kenji.txt

# %%
data = np.loadtxt("LRC_data_kenji.txt", skiprows=3)

# %%
#plt.plot(data[:,0],data[:,1])
plt.plot(data[:,0],data[:,1])
plt.title("Freq vs. Gain")
plt.xlabel("Frequency(Hz)")
plt.ylabel("Gain(dB)")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# As observable, there is a peak at 16.6 kHz.
#This point indicates where a resistance created by the inductor and capacitor is zero.
#Which where the resonance is occuring.

## Conclusion
#The goal of this las has been achieved, we have successfully become familiar with the github, and python.
