# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
data=np.loadtxt("bodeplot.csv", dtype='float', skiprows=3)

# %%
plt.figure()
plt.plot(data[:,0],data[:,1])
plt.title("Frequency vs Gain")
plt.xlabel("Frequency[Hz]")
plt.ylabel("Gain")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Gain')

# %%
plt.plot?
