# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-InvertingNegativeGain.txt"

dT = []
y = []
z = []
y,z = np.loadtxt(fname, dtype=None, skiprows = 5, usecols=(2,5),unpack=True)
dT = np.genfromtxt(fname, dtype=None, skip_header = 5, encoding=None, usecols=(1), unpack=True)

fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage')
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-aea148116381> in <module>
#       7 y = []
#       8 z = []
# ----> 9 y,z = np.loadtxt(fname, dtype=None, skiprows = 5, usecols=(2,5),unpack=True)
#      10 dT = np.genfromtxt(fname, dtype=None, skip_header = 5, encoding=None, usecols=(1), unpack=True)
#      11
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
#     964             fh = iter(fh)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-InvertingNegativeGain.txt"

dT = []
y = []
z = []
y,z = np.loadtxt(fname, dtype=None, skiprows = 5, usecols=(2,5),unpack=True)
dT = np.genfromtxt(fname, dtype=None, skip_header = 5, encoding=None, usecols=(1), unpack=True)

fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage')
ax.grid()
plt.show()
