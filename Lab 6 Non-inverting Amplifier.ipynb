# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

dT,y,z = np.loadtxt(fname, dtype=None, usecols=(1,2,5),unpack=True)
fig,ax = plt.subplots()
dT = []
y = []
z = []
ax.plot(dT,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-a97431e5c947> in <module>
#       4 fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"
#       5
# ----> 6 dT,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
#       7 fig,ax = plt.subplots()
#       8 dT = []
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1139         # converting the data
#    1140         X = None
# -> 1141         for x in read_data(_loadtxt_chunksize):
#    1142             if X is None:
#    1143                 X = np.array(x, dtype)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1059                 continue
#    1060             if usecols:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

dT,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
fig,ax = plt.subplots()
dT = []
y = []
z = []
ax.plot(dT,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-a97431e5c947> in <module>
#       4 fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"
#       5
# ----> 6 dT,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
#       7 fig,ax = plt.subplots()
#       8 dT = []
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1139         # converting the data
#    1140         X = None
# -> 1141         for x in read_data(_loadtxt_chunksize):
#    1142             if X is None:
#    1143                 X = np.array(x, dtype)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1059                 continue
#    1060             if usecols:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

x,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
fig,ax = plt.subplots()

ax.plot(x,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(x,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c1cc7494eb8c> in <module>
#       4 fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"
#       5
# ----> 6 x,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
#       7 fig,ax = plt.subplots()
#       8
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1139         # converting the data
#    1140         X = None
# -> 1141         for x in read_data(_loadtxt_chunksize):
#    1142             if X is None:
#    1143                 X = np.array(x, dtype)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1059                 continue
#    1060             if usecols:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

x,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
fig,ax = plt.subplots()
x = []
y = []
z = []
ax.plot(x,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(x,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-92796122687d> in <module>
#       4 fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"
#       5
# ----> 6 x,y,z = np.loadtxt(fname, dtype=None, usecols=(2,3,6),unpack=True)
#       7 fig,ax = plt.subplots()
#       8 x = []
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1139         # converting the data
#    1140         X = None
# -> 1141         for x in read_data(_loadtxt_chunksize):
#    1142             if X is None:
#    1143                 X = np.array(x, dtype)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1059                 continue
#    1060             if usecols:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

y,z = np.loadtxt(fname, dtype=None, skiprows = 5, usecols=(2,5),unpack=True)
dT = np.genfromtxt(fname, dtype=None, skip_header = 5, encoding=None, usecols=(1), unpack=True)
dT = []
y = []
z = []

fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()

# %%
ax.plot(dT,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

# %%
dT = []

# %%
dT
# Out:
# []

# %%
dT
# Out:
# []

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

dT = []
y = []
z = []
y,z = np.loadtxt(fname, dtype=None, skiprows = 5, usecols=(2,5),unpack=True)
dT = np.genfromtxt(fname, dtype=None, skip_header = 5, encoding=None, usecols=(1), unpack=True)

fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Frequency(Hz)',ylabel='Gain(dB)',title='Frequecy vs Gain')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()

# %%
dT
# Out:
# []

# %%
fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Frequency(Hz)',ylabel='Phase(deg)',title='Phase vs Frequency')
ax.grid()
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage for Ch0')
ax.grid()
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage for Ch1')
ax.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fname = "C:\\Users\\katko\\Documents\\GitHub\\ses330\\Lab 6-NoninvertingAmplifier.txt"

dT = []
y = []
z = []
y,z = np.loadtxt(fname, dtype=None, skiprows = 5, usecols=(2,5),unpack=True)
dT = np.genfromtxt(fname, dtype=None, skip_header = 5, encoding=None, usecols=(1), unpack=True)

fig,ax = plt.subplots()
ax.plot(dT,y)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage')
ax.grid()
plt.show()

fig,ax = plt.subplots()
ax.plot(dT,z)
ax.set(xlabel='Time(s)',ylabel='Voltage(V)',title='Time vs Voltage')
ax.grid()
plt.show()
