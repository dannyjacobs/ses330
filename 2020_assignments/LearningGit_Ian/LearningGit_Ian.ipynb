# %%
import numpy as np
import matplotlib.pyplot as pl

# %% [markdown]
# Load Data. skip lines, use columns

# %%
A = np.genfromtxt('9.9SES330DataFile.csv', comments='#',skip_header=19,names=True, delimiter=',')

# %%
A.dtype
# Out:
# dtype([('Time_s', '<f8'), ('Channel_1_V', '<f8'), ('Channel_2_V', '<f8')])

# %%
A['Time_s'], A['Channel_1_V']
# Out:
# (array([-0.00511935, -0.0051181 , -0.00511685, ...,  0.0051169 ,
#          0.00511815,  0.0051194 ]),
#  array([-0.68038844, -0.67539959, -0.66941297, ...,  0.66427318,
#          0.6702598 ,  0.67491606]))

# %%
pl.figure()
pl.plot(A['Time_s'], A['Channel_1_V'], label='Input')
pl.plot(A['Time_s'], A['Channel_2_V'], label='Output')
pl.xlabel('time (s)')
pl.ylabel('voltage (v)')
pl.legend()
