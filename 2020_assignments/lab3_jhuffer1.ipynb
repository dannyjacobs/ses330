# %% [markdown]
# Lab 3
#
# Jonathan Huffer
#
# 2020_09_09
#
# Plot of sample data from AD2 (WaveForms)

# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
np.recfromcsv?

# %% [markdown]
# Load data. Skip 19 lines of comments, use the actual column names from the file

# %%
D = np.genfromtxt('lab3_jhuffer.csv', comments='#', skip_header=19, names=True, delimiter = ',')

# %%
D[0]
# Out:
# (-0.00511958, 0.57886844, 0.29888816)

# %%
D[0][0]
# Out:
# -0.005119583333333334

# %%
D.shape
# Out:
# (8192,)

# %%
D.size
# Out:
# 8192

# %%
D
# Out:
# array([(-0.00511958,  0.57886844, 0.29888816),
#        (-0.00511833,  0.5453999 , 0.3019056 ),
#        (-0.00511708,  0.51226274, 0.3042525 ), ...,
#        ( 0.00511667, -0.5027286 , 0.20467683),
#        ( 0.00511792, -0.53586577, 0.19528923),
#        ( 0.00511917, -0.5693343 , 0.18590162)],
#       dtype=[('Time_s', '<f8'), ('Channel_1_V', '<f8'), ('Channel_2_V', '<f8')])

# %%
D.dtype
# Out:
# dtype([('Time_s', '<f8'), ('Channel_1_V', '<f8'), ('Channel_2_V', '<f8')])

# %%
D['Time_s']
# Out:
# array([-0.00511958, -0.00511833, -0.00511708, ...,  0.00511667,
#         0.00511792,  0.00511917])

# %%
pl.figure()
pl.plot(D['Time_s'], D['Channel_1_V'], label='Input')
pl.plot(D['Time_s'], D['Channel_1_V'], label='Input')
pl.plot(D['Time_s'], D['Channel_2_V'], label='Output')
pl.xlabel('time (s)')
pl.ylabel('voltage (v)')
pl.legend()
