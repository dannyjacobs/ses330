# %% [markdown]
# # Python Lab Report Tutorial
# # Johnathan McDougal
# # Partners: Patrick Jackson and Kenji Doi
# # 10/15/18
#
# ## Introduction:
# This report serves as a brief tutorial on Git and GitHub. In order to properly demonstrate understanding of the format, real data from a previous hard lab was re-recorded and analyzed. For this lab, the relationship between gain, frequency (resonance), and quality factor were analyzed.
#
# ## 3L.1 & 3L.2
# Before conducting the experiment, a theoretical resonance frequency of the LC voltage divider was needed to calculate a quality factor for the Frequncy vs Gain function.
#
# #### fresonance,t=1/(2LC); given L=10mH, C=0.01µF, fresonance,t=15915.5Hz
#
# Exexuting the experiment, the actual resonance frequency was found to be around 16700. This was determined using the table in Figure 3. In the table, resonance was achieved between 16595Hz and 16982Hz (frequency occurs when phase=0). Furthermore, the table shows a descending phase after resonance as well. From the graph in Figure 2, the gain also drops rapidly after resonance.

# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("John_Data.txt", skiprows=3)

# %%
#plt.plot(data[:,0],data[:,1])
plt.plot(data[:,0],data[:,1])
plt.title("Freq vs. Gain")
plt.xlabel("Frequency(Hz)")
plt.ylabel("Gain(dB)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Gain(dB)')

# %% [markdown]
# _Figure 2, After achieving resonance frequency gain begins to rapidly descend._

# %% [markdown]
# ![data.PNG](attachment:data.PNG)
# _Figure 3, This table simply gives more information about what's goin on in the graph. However, the table also displays an increasingly negative phase value after reaching resonance_

# %% [markdown]
# Using this information, given deltaf=0.54kHz and the formula:
# #### Q=fresonance/deltaf
# the quality factor was calculated to be 30.9
