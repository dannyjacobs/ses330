# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("lrc_Jackson.txt", skiprows=3)

# %%
#plt.plot(data[:,0],data[:,1])
plt.plot(data[:,0],data[:,1])
plt.title("Freq vs. Gain")
plt.xlabel("Frequency(Hz)")
plt.ylabel("Gain(dB)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Gain(dB)')

# %%
plt.plot?
