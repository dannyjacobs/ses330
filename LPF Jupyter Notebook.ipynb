# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f, g, p = np.loadtxt('./SES 330 Tran Engelson LPF.txt', skiprows = 3, unpack = True)

# %%
plt.plot(f,g)
plt.xlabel('Freq (Hz)')
plt.ylabel('Gain (dB)')
plt.title('Low Pass Filter')
# Out:
# Text(0.5,1,'Low Pass Filter')

# %%
plt.plot(f,g)
plt.xlabel('Freq (Hz)')
plt.ylabel('Phase (deg)')
plt.title('Low Pass Filter')
# Out:
# Text(0.5,1,'Low Pass Filter')
